# %%
import pandas as pd

data_ev=pd.read_json("Script_generador_tickets_sinteticos_electricos/data/tickets_ev_sinteticos.json")

# %%
data_ev
# Out:
#            idTicket idEmpresa       empresaNombre  idUsuario fechaEmision  \
# 0    T-56D7BD446D80     EMP04  Transporte_04 S.L.  EMP04-U28   2025-04-13
# 1    T-3FB3E9398BAF     EMP04  Transporte_04 S.L.  EMP04-U28   2025-07-18
# 2    T-6721290A6DF9     EMP04  Transporte_04 S.L.  EMP04-U28   2025-01-12
# 3    T-731247343475     EMP04  Transporte_04 S.L.  EMP04-U28   2025-06-30
# 4    T-92B9316F8EF0     EMP04  Transporte_04 S.L.  EMP04-U28   2025-04-12
# ..              ...       ...                 ...        ...          ...
# 445  T-39F73E0B8FA7     EMP06  Transporte_06 S.L.  EMP06-U36   2025-01-15
# 446  T-E8136BCDE479     EMP06  Transporte_06 S.L.  EMP06-U36   2025-01-22
# 447  T-321083149994     EMP06  Transporte_06 S.L.  EMP06-U36   2025-04-29
# 448  T-78B1849AF40E     EMP06  Transporte_06 S.L.  EMP06-U36   2025-02-26
# 449  T-4E8445B7F451     EMP06  Transporte_06 S.L.  EMP06-U36   2025-05-19
#
#     horaEmision          metodoPago  \
# 0      04:23:15  Tarjeta de empresa
# 1      18:28:03  Tarjeta de empresa
# 2      16:21:40  Tarjeta de empresa
# 3      06:55:20  Tarjeta de empresa
# 4      14:23:10  Tarjeta de empresa
# ..          ...                 ...
# 445    10:19:20  Tarjeta de empresa
# 446    06:41:02  Tarjeta de empresa
# 447    08:35:42  Tarjeta de empresa
# 448    14:13:37  Tarjeta de empresa
# 449    12:41:43  Tarjeta de empresa
#
#                                               estacion  \
# 0    {'id': 'ES*WEN*ESGASVALDEMORO14', 'provincia':...
# 1    {'id': 'ES*IBD*E157199', 'provincia': 'TARRAGO...
# 2    {'id': 'ES*EDP*E00923', 'provincia': 'Principa...
# 3    {'id': 'ES*ESX*E21XP22T3KKJAK006051', 'provinc...
# 4    {'id': 'ES*EVC*E14765', 'provincia': 'Navarra'...
# ..                                                 ...
# 445  {'id': 'ES*REP*E13476*1', 'provincia': 'Comuni...
# 446  {'id': 'ES*IBD*E397991', 'provincia': 'VALENCI...
# 447  {'id': 'ES*ENE*E044', 'provincia': 'Coruña, A'...
# 448  {'id': 'ES*MOE*EC8A233S023CNWAUQEH', 'provinci...
# 449  {'id': 'ES*ESX*E619460527800051', 'provincia':...
#
#                                                 lineas  baseImponible   iee  \
# 0    [{'producto': 'Electricidad', 'kwh': 76.92, 'p...          42.92  2.19
# 1    [{'producto': 'Electricidad', 'kwh': 44.94, 'p...          23.73  1.21
# 2    [{'producto': 'Electricidad', 'kwh': 45.55, 'p...          24.78  1.27
# 3    [{'producto': 'Electricidad', 'kwh': 63.51, 'p...          36.65  1.87
# 4    [{'producto': 'Electricidad', 'kwh': 46.32, 'p...          24.55  1.25
# ..                                                 ...            ...   ...
# 445  [{'producto': 'Electricidad', 'kwh': 41.79, 'p...          23.61  1.21
# 446  [{'producto': 'Electricidad', 'kwh': 32.3, 'pr...          17.96  0.92
# 447  [{'producto': 'Electricidad', 'kwh': 33.68, 'p...          18.63  0.95
# 448  [{'producto': 'Electricidad', 'kwh': 43.81, 'p...          23.61  1.21
# 449  [{'producto': 'Electricidad', 'kwh': 41.24, 'p...          23.80  1.22
#
#       iva  total moneda         tipoDocumento
# 0    9.48  54.59    EUR  Factura simplificada
# 1    5.24  30.18    EUR  Factura simplificada
# 2    5.46  31.51    EUR  Factura simplificada
# 3    8.09  46.61    EUR  Factura simplificada
# 4    5.42  31.22    EUR  Factura simplificada
# ..    ...    ...    ...                   ...
# 445  5.21  30.03    EUR  Factura simplificada
# 446  3.96  22.84    EUR  Factura simplificada
# 447  4.11  23.69    EUR  Factura simplificada
# 448  5.21  30.03    EUR  Factura simplificada
# 449  5.24  30.26    EUR  Factura simplificada
#
# [450 rows x 15 columns]

# %%
data_ev["lineas"]
# Out:
# 0      [{'producto': 'Electricidad', 'kwh': 76.92, 'p...
# 1      [{'producto': 'Electricidad', 'kwh': 44.94, 'p...
# 2      [{'producto': 'Electricidad', 'kwh': 45.55, 'p...
# 3      [{'producto': 'Electricidad', 'kwh': 63.51, 'p...
# 4      [{'producto': 'Electricidad', 'kwh': 46.32, 'p...
#                              ...
# 445    [{'producto': 'Electricidad', 'kwh': 41.79, 'p...
# 446    [{'producto': 'Electricidad', 'kwh': 32.3, 'pr...
# 447    [{'producto': 'Electricidad', 'kwh': 33.68, 'p...
# 448    [{'producto': 'Electricidad', 'kwh': 43.81, 'p...
# 449    [{'producto': 'Electricidad', 'kwh': 41.24, 'p...
# Name: lineas, Length: 450, dtype: object

# %%
estacion_df = pd.json_normalize(data_ev["estacion"])
data_ev = data_ev.drop(columns=["estacion"]).join(estacion_df.add_prefix("estacion."))

# %%
df_exploded = data_ev.explode("lineas").reset_index(drop=True)

# Normaliza la columna "lineas" (dict → columnas)
lineas_normalizadas = pd.json_normalize(df_exploded["lineas"])

# Une las nuevas columnas con el dataset original
data_ev = df_exploded.drop(columns=["lineas"]).join(lineas_normalizadas.add_prefix("lineas."))

# %%
import datetime
def hora(x):
    datetime.strptime()

# %%
data_ev["fechaEmision"]=pd.to_datetime(data_ev["fechaEmision"])

data_ev["horaEmision"]=pd.to_datetime(data_ev["horaEmision"], format="%H:%M:%S")

# %%
data_ev["fechaEmision"]
# Out:
# 0     2025-04-13
# 1     2025-07-18
# 2     2025-01-12
# 3     2025-06-30
# 4     2025-04-12
#          ...
# 445   2025-01-15
# 446   2025-01-22
# 447   2025-04-29
# 448   2025-02-26
# 449   2025-05-19
# Name: fechaEmision, Length: 450, dtype: datetime64[ns]

# %%
data_ev["horaEmision"]
# Out:
# 0     1900-01-01 04:23:15
# 1     1900-01-01 18:28:03
# 2     1900-01-01 16:21:40
# 3     1900-01-01 06:55:20
# 4     1900-01-01 14:23:10
#               ...
# 445   1900-01-01 10:19:20
# 446   1900-01-01 06:41:02
# 447   1900-01-01 08:35:42
# 448   1900-01-01 14:13:37
# 449   1900-01-01 12:41:43
# Name: horaEmision, Length: 450, dtype: datetime64[ns]

# %%
data_ev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 28 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   idTicket                           450 non-null    object
#  1   idEmpresa                          450 non-null    object
#  2   empresaNombre                      450 non-null    object
#  3   idUsuario                          450 non-null    object
#  4   fechaEmision                       450 non-null    datetime64[ns]
#  5   horaEmision                        450 non-null    datetime64[ns]
#  6   metodoPago                         450 non-null    object
#  7   baseImponible                      450 non-null    float64
#  8   iee                                450 non-null    float64
#  9   iva                                450 non-null    float64
#  10  total                              450 non-null    float64
#  11  moneda                             450 non-null    object
#  12  tipoDocumento                      450 non-null    object
#  13  estacion.id                        450 non-null    object
#  14  estacion.provincia                 450 non-null    object
#  15  estacion.municipio                 450 non-null    object
#  16  estacion.direccion                 450 non-null    object
#  17  estacion.lat                       450 non-null    float64
#  18  estacion.lon                       450 non-null    float64
#  19  estacion.empresa                   450 non-null    object
#  20  estacion.nifEmpresa                450 non-null    object
#  21  estacion.potenciaMaxKW             450 non-null    float64
#  22  estacion.tarifa                    450 non-null    object
#  23  lineas.producto                    450 non-null    object
#  24  lineas.kwh                         450 non-null    float64
#  25  lineas.precioUnitarioSinImpuestos  450 non-null    float64
#  26  lineas.precioUnitario              450 non-null    float64
#  27  lineas.importe                     450 non-null    float64
# dtypes: datetime64[ns](2), float64(11), object(15)
# memory usage: 98.6+ KB

# %%
data_ev['empresaNombre']
# Out:
# 0      Transporte_04 S.L.
# 1      Transporte_04 S.L.
# 2      Transporte_04 S.L.
# 3      Transporte_04 S.L.
# 4      Transporte_04 S.L.
#               ...
# 445    Transporte_06 S.L.
# 446    Transporte_06 S.L.
# 447    Transporte_06 S.L.
# 448    Transporte_06 S.L.
# 449    Transporte_06 S.L.
# Name: empresaNombre, Length: 450, dtype: object

# %%
[['empresaNombre', 'idUsuario', 'fechaEmision', 'horaEmision', 'metodoPago', 'baseImponible', 'total', 'estacion.id', 'estacion.provincia']]
# Out:
# [['empresaNombre',
#   'idUsuario',
#   'fechaEmision',
#   'horaEmision',
#   'metodoPago',
#   'baseImponible',
#   'total',
#   'estacion.id',
#   'estacion.provincia']]

# %%
from skrub import TableReport

TableReport(data_ev)
# Out:
# Processing column  28 / 28
# <TableReport: use .open() to display>

# %% [markdown]
# * No parceqeue haya diferencias significativas entre la hora y la
# * Hay tres empresas y tres emplados por empresa
# * El metodo de pago mas comuns es la tarjete de empresa
# * Las fechas van desde enero a 30 julio
# * Lo normal es gastar 28 euros en electriduad (unos 41.8 kwh)
# * Barcelnoa Madris son los que tienen mas gpuesto
# * Por algun mtotivo esta estacion 'Parking Publico Ciudad Imagen - C. Luis' ha vendio casi el doble que el resto
# * el IVA varia bastante mas de lo esperado

# %%
data_ev["idEmpresa"].value_counts()
# Out:
# idEmpresa
# EMP04    150
# EMP05    150
# EMP06    150
# Name: count, dtype: int64

# %%
data_ev.fechaEmision.max()
# Out:
# Timestamp('2025-07-30 00:00:00')

# %%
data_ev['estacion.empresa'].value_counts()
# Out:
# estacion.empresa
# ENDESA X WAY S.L.                                90
# IBERDROLA CLIENTES S.A.U                         85
# REPSOL SOLUCIONES ENERGÉTICAS SA                 45
# Etecnic Movilidad Electrica SRL                  40
# REPSOL COMERCIAL DE PRODUCTOS PETROLIFEROS SA    34
# WENEA EMOBILITY SERVICES S.L.                    23
# EDP CLIENTES SAU                                 16
# CHARGING TOGETHER SL                             13
# ERANOVUM E-MOBILITY S.L.                         11
# PLENOIL S.L.                                     10
# EXANERGÍA S.L.                                    8
# ACCIONA Recarga                                   5
# FENIE ENERGIA SA                                  4
# Prio Recharge Sl.                                 4
# BARCELONA DE SERVEIS MUNICIPALS SA                4
# (ZUNDER) Grupo Easychargar SA                     4
# IONITY GmbH Sucursal en España                    4
# ION SMART ENERGY 2000 SL                          3
# Tesla Spain SLU                                   3
# Atlante Iberia SL                                 3
# Allego Spain S.L.U                                3
# Punto Recargas SL                                 3
# CENTROS COMERCIALES CARREFOUR SA                  3
# Wenea Services Spain S.L.                         3
# AJUNTAMENT DE CALVIÀ                              3
# MAKSU ESPAÑA SL                                   2
# GESTION INTELIGENTE DE CARGAS S.L.                2
# CEPSA COMERCIAL PETRÓLEOS.A.U.                    2
# ENERGEA CONSULTING Y ASESORES SL                  2
# GESTION DE ENERGIA Y ENTORNOS SOSTENIBLES SL      2
# Naturgy Iberia                                    1
# Energía Distribuida del Norte S.A.                1
# OESTE SOLUCIONES ENERGETICAS S.L.                 1
# BP Energía España SAU                             1
# REMO SUSTAINABLE MOBILITY S.L                     1
# AYUNTAMIENTO DE FELANITX                          1
# AJUNTAMENT DES CASTELL                            1
# Consejo Insular de la Energía de Gran Canaria     1
# EFICIENCIA Y SERVICIOS RENOVABLES SL              1
# MARINA SOUTH BEACH SLU                            1
# Alcudiamar S.L.                                   1
# Ingenieria de Recarga SLU                         1
# PARKING MOGAN SA                                  1
# PAVAPARK MOVILIDAD SL                             1
# Galp Energía España S.A.U.                        1
# The F Charging Espana S.L.U.                      1
# Name: count, dtype: int64

# %%
data_ev['lineas.producto'].value_counts()
# Out:
# lineas.producto
# Electricidad    450
# Name: count, dtype: int64

# %%
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
data_ev.groupby('estacion.empresa')["lineas.precioUnitario"].median()



# Creating trace1
trace1 = go.Bar(
                    x = data_ev['estacion.empresa'],
                    y = data_ev['lineas.precioUnitario'],
                    name = 'precio unitacio',
                    
                    
                    )

fig = go.Figure(data = trace1)

iplot(fig)

# %% [markdown]
# Iberdrola y endesa son los principales vendedores (aunque parce que varioan mucho los precion seguramente porque son los que mas venden)
# Repsol tampbien vende mucho aunque este divido en dos subcompañias (una dirigiaa gasolina y otra a energia)
# Wenea EDP Etecnic y Charging togetehe

# %%
trace1
# Out:
# Bar({
#     'name': 'precio unitacio',
#     'x': array(['WENEA EMOBILITY SERVICES S.L.', 'IBERDROLA CLIENTES S.A.U',
#                 'EDP CLIENTES SAU', ..., 'ENERGEA CONSULTING Y ASESORES SL',
#                 'CEPSA COMERCIAL PETRÓLEOS.A.U.', 'ENDESA X WAY S.L.'], dtype=object),
#     'y': array([0.71 , 0.672, 0.692, ..., 0.703, 0.686, 0.734])
# })

# %%
data_ev.groupby('lineas.kwh')["lineas.precioUnitario"].median()


trace1 = go.Scatter(
                    x = data_ev['lineas.kwh'],
                    y = data_ev['lineas.precioUnitario'],
                    name = 'precio unitacio',
                    mode = 'markers',


                    
                    
                    )
layout=go.Layout(
            xaxis= dict(title= 'kwh',ticklen= 5,zeroline= False),
              yaxis= dict(title= 'precioUnitario',ticklen= 5,zeroline= False)
)
fig = go.Figure(data = trace1)
iplot(fig)

# %% [markdown]
# Esto es interesante: hay dos dos tipos de precios pero no es por kwh

# %%
data_ev.groupby('lineas.kwh')["lineas.precioUnitario"].median()


trace1 = go.Scatter(
                    x = data_ev['estacion.tarifa'],
                    y = data_ev['lineas.precioUnitario'],
                    name = 'precio unitacio',
                    mode = 'markers',


                    
                    
                    )
layout=go.Layout(
            xaxis= dict(title= 'tarifa',ticklen= 5,zeroline= False),
              yaxis= dict(title= 'precioUnitario',ticklen= 5,zeroline= False)
)
fig = go.Figure(data = trace1)
iplot(fig)

# %% [markdown]
# La diferencia de precios es si es de corriente directa o alterna (se supono que DC es mas rapido que AC po)

# %%
data_ev.groupby('estacion.empresa')["lineas.precioUnitario"].median()
# Out:
# estacion.empresa
# (ZUNDER) Grupo Easychargar SA                    0.6925
# ACCIONA Recarga                                  0.7060
# AJUNTAMENT DE CALVIÀ                             0.7210
# AJUNTAMENT DES CASTELL                           0.6880
# AYUNTAMIENTO DE FELANITX                         0.5530
# Alcudiamar S.L.                                  0.6740
# Allego Spain S.L.U                               0.6940
# Atlante Iberia SL                                0.5390
# BARCELONA DE SERVEIS MUNICIPALS SA               0.5230
# BP Energía España SAU                            0.6920
# CENTROS COMERCIALES CARREFOUR SA                 0.6930
# CEPSA COMERCIAL PETRÓLEOS.A.U.                   0.6910
# CHARGING TOGETHER SL                             0.7080
# Consejo Insular de la Energía de Gran Canaria    0.6780
# EDP CLIENTES SAU                                 0.6720
# EFICIENCIA Y SERVICIOS RENOVABLES SL             0.5520
# ENDESA X WAY S.L.                                0.6920
# ENERGEA CONSULTING Y ASESORES SL                 0.7120
# ERANOVUM E-MOBILITY S.L.                         0.6960
# EXANERGÍA S.L.                                   0.7085
# Energía Distribuida del Norte S.A.               0.7170
# Etecnic Movilidad Electrica SRL                  0.6830
# FENIE ENERGIA SA                                 0.7105
# GESTION DE ENERGIA Y ENTORNOS SOSTENIBLES SL     0.7065
# GESTION INTELIGENTE DE CARGAS S.L.               0.7220
# Galp Energía España S.A.U.                       0.6840
# IBERDROLA CLIENTES S.A.U                         0.6970
# ION SMART ENERGY 2000 SL                         0.6880
# IONITY GmbH Sucursal en España                   0.6850
# Ingenieria de Recarga SLU                        0.5330
# MAKSU ESPAÑA SL                                  0.5375
# MARINA SOUTH BEACH SLU                           0.5610
# Naturgy Iberia                                   0.6960
# OESTE SOLUCIONES ENERGETICAS S.L.                0.7160
# PARKING MOGAN SA                                 0.5190
# PAVAPARK MOVILIDAD SL                            0.7000
# PLENOIL S.L.                                     0.6940
# Prio Recharge Sl.                                0.7090
# Punto Recargas SL                                0.7030
# REMO SUSTAINABLE MOBILITY S.L                    0.7010
# REPSOL COMERCIAL DE PRODUCTOS PETROLIFEROS SA    0.6950
# REPSOL SOLUCIONES ENERGÉTICAS SA                 0.6940
# Tesla Spain SLU                                  0.7160
# The F Charging Espana S.L.U.                     0.7060
# WENEA EMOBILITY SERVICES S.L.                    0.6920
# Wenea Services Spain S.L.                        0.6930
# Name: lineas.precioUnitario, dtype: float64

# %% [markdown]
# Lo mas barato es el gasoleo A

# %%
import folium
from folium import plugins
mapa = folium.Map(location=[40, -5], zoom_start=6, )
for x in range(len(data_ev)):
         
    
    folium.Marker(location=data_ev.iloc[x][["estacion.lat","estacion.lon"]], popup=data_ev.iloc[x]["lineas.precioUnitario"]
              
              ).add_to(mapa)

mapa
# Out:
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# ...
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb932507e7140d9eee829d295e066271 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb932507e7140d9eee829d295e066271&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb932507e7140d9eee829d295e066271 = L.map(
#                 &quot;map_fb932507e7140d9eee829d295e066271&quot;,
#                 {
#                     center: [40.0, -5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed99cc4af6dfcc4429010d86e35e21f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed99cc4af6dfcc4429010d86e35e21f7.addTo(map_fb932507e7140d9eee829d295e066271);
#
#
#             var marker_de81a5d61bdff934679fbf7a80279a06 = L.marker(
#                 [40.17221, -3.665604],
#                 {
# }
#             ).addTo(map_fb932507e7140d9eee829d295e066271);
#
#
#         var popup_80b5642712fbae29b3d6747bb0cee34e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3edcdd768756c592b0c7960cdc25fb31 = $(`&lt;div id=&quot;html_3edcdd768756c592b0c7960cdc25fb31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.71&lt;/div&gt;`)[0];
#                 popup_80b5642712fbae29b3d6747bb0cee34e.setContent(html_3edcdd768756c592b0c7960cdc25fb31);
#
#
#
#         marker_de81a5d61bdff934679fbf7a80279a06.bindPopup(popup_80b5642712fbae29b3d6747bb0cee34e)
#         ;
#
#
#
#
#             var marker_8e561fa858d8b4eaa5d4fb1345082d96 = L.marker(
#                 [41.072998, 1.108934],
#                 {
# }
#             ).addTo(map_fb932507e7140d9eee829d295e066271);
#
#
#         var popup_e272e4a4294c57cdc825fd35b3a2775d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a8bdadbc26af83fed5816494c5ba43b = $(`&lt;div id=&quot;html_9a8bdadbc26af83fed5816494c5ba43b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.672&lt;/div&gt;`)[0];
#                 popup_e272e4a4294c57cdc825fd35b3a2775d.setContent(html_9a8bdadbc26af83fed5816494c5ba43b);
#
#
#
#         marker_8e561fa858d8b4eaa5d4fb1345082d96.bindPopup(popup_e272e4a4294c57cdc825fd35b3a2775d)
#         ;
#
#
#
#
#             var marker_7c05ca11d87762796a81135a6eafe1be = L.marker(
#                 [43.434171, -5.87073],
#                 {
# }
#             ).addTo(map_fb932507e7140d9eee829d295e066271);
#
#
#         var popup_abc1029d5103ed5d8d8cf28fcd09f654 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76fef838d760086d7ef7e3c618e6af50 = $(`&lt;div id=&quot;html_76fef838d760086d7ef7e3c618e6af50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.6920000000000001&lt;/div&gt;`)[0];
#                 popup_abc1029d5103ed5d8d8cf28fcd09f654.setContent(html_76fef838d760086d7ef7e3c618e6af50);
#
#
#
#         marker_7c05ca11d87762796a81135a6eafe1be.bindPopup(popup_abc1029d5103ed5d8d8cf28fcd09f654)
#         ;
#
#
#
#
#             var marker_6553bb5c2f6f98d4028f877fd9e8de3c = L.marker(
#                 [40.407267, -3.688354],
#                 {
# }
#             ).addTo(map_fb932507e7140d9eee829d295e066271);
#
#
#         var popup_27e9cec95eefa325d61876cbbf0e3fe8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fce7b65041bed22dee460b25c72073e = $(`&lt;div id=&quot;html_7fce7b65041bed22dee460b25c72073e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.734&lt;/div&gt;`)[0];
#                 popup_27e9cec95eefa325d61876cbbf0e3fe8.setContent(html_7fce7b65041bed22dee460b25c72073e);
#
#
#
#         marker_6553bb5c2f6f98d4028f877fd9e8de3c.bindPopup(popup_27e9cec95eefa325d61876cbbf0e3fe8)
#         ;
#
#
#
#
#             var marker_1a62da73d0864af24e8e74babb1df8c6 = L.marker(
#                 [42.999279, -1.889054],
#                 {
# }
#             ).addTo(map_fb932507e7140d9eee829d295e066271);
#
#
#         var popup_939323856d894b51c278c3e664fa6d7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1eea622a1dca9386579d86746a562a79 = $(`&lt;div id=&quot;html_1eea622a1dca9386579d86746a562a79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.674&lt;/div&gt;`)[0];
#                 popup_939323856d894b51c278c3e664fa6d7e.setContent(html_1eea622a1dca9386579d86746a562a79);
#
#
#
#         marker_1a62da73d0864af24e8e74babb1df8c6.bindPopup(

# %%
['idEmpresa', 'idUsuario']
# Out:
# ['idEmpresa', 'idUsuario']

# %%
data_ev.groupby('idEmpresa')['idUsuario'].value_counts()
# Out:
# idEmpresa  idUsuario
# EMP04      EMP04-U28    50
#            EMP04-U29    50
#            EMP04-U30    50
# EMP05      EMP05-U31    50
#            EMP05-U32    50
#            EMP05-U33    50
# EMP06      EMP06-U34    50
#            EMP06-U35    50
#            EMP06-U36    50
# Name: count, dtype: int64

# %% [markdown]
# Todos los usuarisos compranrpn el mismp numero de veces

# %%
data_ev.groupby('idEmpresa')[['lineas.importe']].mean()
# Out:
#            lineas.importe
# idEmpresa
# EMP04           28.019333
# EMP05           28.232267
# EMP06           27.747467

# %%
data_ev.groupby('idEmpresa')['estacion.tarifa'].value_counts()
# Out:
# idEmpresa  estacion.tarifa
# EMP04      DC                 124
#            AC                  26
# EMP05      DC                 124
#            AC                  26
# EMP06      DC                 119
#            AC                  31
# Name: count, dtype: int64

# %%
data_ev.columns
# Out:
# Index(['idTicket', 'idEmpresa', 'empresaNombre', 'idUsuario', 'fechaEmision',
#        'horaEmision', 'metodoPago', 'baseImponible', 'iee', 'iva', 'total',
#        'moneda', 'tipoDocumento', 'estacion.id', 'estacion.provincia',
#        'estacion.municipio', 'estacion.direccion', 'estacion.lat',
#        'estacion.lon', 'estacion.empresa', 'estacion.nifEmpresa',
#        'estacion.potenciaMaxKW', 'estacion.tarifa', 'lineas.producto',
#        'lineas.kwh', 'lineas.precioUnitarioSinImpuestos',
#        'lineas.precioUnitario', 'lineas.importe'],
#       dtype='object')

# %% [markdown]
# Todas las empresas pagan parecidas y tienen poblaciones parecidas en todos

# %%
display(data_ev.groupby('idEmpresa')['fechaEmision'].value_counts())
# Out:
# idEmpresa  fechaEmision
# EMP04      2025-01-02      3
#            2025-02-04      3
#            2025-02-16      3
#            2025-02-24      3
#            2025-02-27      3
#                           ..
# EMP06      2025-07-19      1
#            2025-07-20      1
#            2025-07-21      1
#            2025-07-24      1
#            2025-07-30      1
# Name: count, Length: 320, dtype: int64

# %%
from folium.plugins import HeatMap
df_map = data_ev.groupby(['estacion.lat', 'estacion.lon'])['lineas.kwh'].sum().reset_index()

# Crear mapa centrado (ejemplo: centro de España)
m = folium.Map(location=[40.0, -3.7], zoom_start=6, tiles="CartoDB positron")

# Preparar datos para el HeatMap (lat, lon, peso)
heat_data = [[row['estacion.lat'], row['estacion.lon'], row['lineas.kwh']] for index, row in df_map.iterrows()]

# Añadir capa HeatMap
HeatMap(heat_data, radius=15, blur=10, max_zoom=1).add_to(m)

# Mostrar en Jupyter
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa56c7d330142c81b4f16f0f12702dd0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa56c7d330142c81b4f16f0f12702dd0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa56c7d330142c81b4f16f0f12702dd0 = L.map(
#                 &quot;map_fa56c7d330142c81b4f16f0f12702dd0&quot;,
#                 {
#                     center: [40.0, -3.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75a286bafde61095e6919cd84316cb68 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75a286bafde61095e6919cd84316cb68.addTo(map_fa56c7d330142c81b4f16f0f12702dd0);
#
#
#             var heat_map_ee5202e13adac2eb8c8bcdff53193a3f = L.heatLayer(
#                 [[27.7679069, -15.6011738, 22.5], [27.795289, -15.704981, 43.19], [27.8191842, -15.763147, 50.83], [28.009833, -15.390083, 43.81], [28.0529798, -16.7152284, 32.5], [28.0962706, -15.415256, 57.1], [28.1143065, -15.4487773, 23.59], [28.115359, -15.420044, 37.11], [28.128655, -15.450266, 32.21], [28.178401, -17.265379, 30.05], [28.415429, -16.542907, 51.25], [28.4591687, -16.256747, 41.57], [28.496343, -13.863596, 25.79], [28.496423, -13.863676, 55.14], [28.6108129, -13.9354046, 17.08], [28.73385, -13.871110999999999, 53.3], [36.0690147, -5.68419937, 71.16], [36.110199, -5.824447, 69.93], [36.48897, -4.953049, 48.89], [36.494718, -6.264587, 47.71], [36.507613, -4.950527, 72.39], [36.519686, -6.278517, 54.49], [36.671657, -6.121838, 26.6], [36.6816608, -4.4701718, 71.97], [36.694351, -6.100985, 39.09], [36.695402, -4.494141, 54.56], [36.695571, -4.452784, 30.81], [36.7063696, -4.4706381, 11.07], [36.706772, -6.124923, 34.4], [36.71679, -4.46148, 49.16], [36.721677, -4.380575, 29.31], [36.725453, -4.254919, 44.75], [36.737745, -3.513338, 53.34], [36.74312, -5.16662, 52.74], [36.7716, -6.3563, 32.08], [36.796245, -2.687973, 66.01], [37.003627, -2.789463, 44.14], [37.0262734, -4.5372334, 72.42], [37.129556, -3.58354, 107.42], [37.143806, -3.605513, 37.68], [37.153078, -3.61458, 47.14], [37.183885, -3.958342, 21.8], [37.187365, -3.610366, 61.83], [37.190264, -3.605473, 129.74], [37.191858, -6.972194, 39.61], [37.249896, -1.874, 24.8], [37.258448, -6.95822, 25.2], [37.258477, -6.95825, 34.53], [37.275491, -6.925494, 30.37], [37.3015428, -6.59596444, 52.49], [37.306283, -6.873187, 39.52], [37.325061, -4.373766, 57.41], [37.3621274, -6.000727, 54.94], [37.363816, -5.955892, 49.57], [37.364876, -5.978485, 11.3], [37.371436, -5.959059, 44.0], [37.3783, -6.08278, 45.93], [37.393331, -3.027261, 16.96], [37.393397, -5.982012, 35.81], [37.40406, -4.497797, 51.08], [37.410237, -5.9253979999999995, 26.58], [37.412859, -5.981811, 39.76], [37.426014, -5.983239, 27.31], [37.42603, -5.97097, 47.38], [37.444389, -4.274673, 33.2], [37.446878, -7.106609, 71.55], [37.460876, -5.656487, 70.21], [37.475284, -4.440176, 42.2], [37.478254, -6.008443, 24.27], [37.573178, -0.922659, 26.74], [37.607613, -0.803816, 25.15], [37.66721, -1.70185, 40.29], [37.762187, -3.94021, 60.84], [37.76577, -6.5769400000000005, 29.53], [37.784414, -3.776479, 43.78], [37.7978776, -0.8383811, 57.9], [37.900654, -4.768967, 53.58], [37.957262, -2.434524, 47.81], [37.973403, -3.802544, 29.65], [37.992193, -0.674701, 24.94], [37.993743, -1.130865, 38.06], [38.019988, -3.370622, 20.19], [38.027699, -1.169062, 49.18], [38.035111, -1.253361, 44.15], [38.251086, -2.890412, 42.66], [38.272536, -0.6685329999999999, 45.29], [38.275878, -0.538824, 63.41], [38.336721, -0.501862, 48.78], [38.345149, -0.550284, 33.94], [38.3588695, -0.48505669999999995, 33.41], [38.376096, -0.498731, 57.28], [38.385687, -0.765061, 55.46], [38.5366, -0.1517, 33.46], [38.537481, -0.179914, 48.68], [38.568, -0.209723, 47.33], [38.615911, -1.08408, 32.48], [38.637127, -0.866327, 28.48], [38.667596, -4.037644, 58.52], [38.6999809, 0.13428199999999998, 60.69], [38.729447, 0.091984, 53.66], [38.7600947, -3.3876474, 51.77], [38.779339, -3.389307, 19.57], [38.794902, 0.179311, 44.19], [38.81955, -0.378237, 58.72], [38.821998, -0.001921, 25.54], [38.839523, -6.6469570000000004, 59.83], [38.8675825, -6.9896437, 35.91], [38.87883, -1.1002, 38.51], [38.89818, -6.99012, 35.56], [38.913286, -0.5532311999999999, 19.35], [38.94926, -0.195079, 42.96], [38.9710051, -0.1539121, 3

# %%
from folium.plugins import HeatMap
df_map = data_ev.groupby(['estacion.lat', 'estacion.lon'])['lineas.importe'].sum().reset_index()

# Crear mapa centrado (ejemplo: centro de España)
m = folium.Map(location=[40.0, -3.7], zoom_start=6, tiles="CartoDB positron")

# Preparar datos para el HeatMap (lat, lon, peso)
heat_data = [[row['estacion.lat'], row['estacion.lon'], row['lineas.importe']] for index, row in df_map.iterrows()]

# Añadir capa HeatMap
HeatMap(heat_data, radius=15, blur=10, max_zoom=1).add_to(m)

# Mostrar en Jupyter
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c94a31f492a326b3031bea4baa0625b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c94a31f492a326b3031bea4baa0625b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c94a31f492a326b3031bea4baa0625b9 = L.map(
#                 &quot;map_c94a31f492a326b3031bea4baa0625b9&quot;,
#                 {
#                     center: [40.0, -3.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a770a1547eeb3a34b54cd12fc98635f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a770a1547eeb3a34b54cd12fc98635f.addTo(map_c94a31f492a326b3031bea4baa0625b9);
#
#
#             var heat_map_e2c80bb6b3051e65a3553919907266f4 = L.heatLayer(
#                 [[27.7679069, -15.6011738, 15.25], [27.795289, -15.704981, 22.52], [27.8191842, -15.763147, 26.38], [28.009833, -15.390083, 30.03], [28.0529798, -16.7152284, 23.02], [28.0962706, -15.415256, 40.01], [28.1143065, -15.4487773, 13.23], [28.115359, -15.420044, 20.86], [28.128655, -15.450266, 23.19], [28.178401, -17.265379, 21.25], [28.415429, -16.542907, 36.37], [28.4591687, -16.256747, 29.5], [28.496343, -13.863596, 13.02], [28.496423, -13.863676, 28.33], [28.6108129, -13.9354046, 12.12], [28.73385, -13.871110999999999, 36.94], [36.0690147, -5.68419937, 50.23], [36.110199, -5.824447, 49.01], [36.48897, -4.953049, 35.88], [36.494718, -6.264587, 24.45], [36.507613, -4.950527, 51.1], [36.519686, -6.278517, 39.22], [36.671657, -6.121838, 19.42], [36.6816608, -4.4701718, 49.61], [36.694351, -6.100985, 27.69], [36.695402, -4.494141, 38.1], [36.695571, -4.452784, 21.2], [36.7063696, -4.4706381, 8.05], [36.706772, -6.124923, 23.45], [36.71679, -4.46148, 32.82], [36.721677, -4.380575, 21.21], [36.725453, -4.254919, 30.79], [36.737745, -3.513338, 37.52], [36.74312, -5.16662, 36.69], [36.7716, -6.3563, 22.36], [36.796245, -2.687973, 45.33], [37.003627, -2.789463, 31.27], [37.0262734, -4.5372334, 49.55], [37.129556, -3.58354, 77.80000000000001], [37.143806, -3.605513, 27.6], [37.153078, -3.61458, 32.32], [37.183885, -3.958342, 15.36], [37.187365, -3.610366, 32.95], [37.190264, -3.605473, 71.35], [37.191858, -6.972194, 27.51], [37.249896, -1.874, 17.57], [37.258448, -6.95822, 17.34], [37.258477, -6.95825, 23.58], [37.275491, -6.925494, 21.63], [37.3015428, -6.59596444, 36.98], [37.306283, -6.873187, 26.99], [37.325061, -4.373766, 40.01], [37.3621274, -6.000727, 39.27], [37.363816, -5.955892, 34.8], [37.364876, -5.978485, 5.86], [37.371436, -5.959059, 31.11], [37.3783, -6.08278, 31.6], [37.393331, -3.027261, 11.6], [37.393397, -5.982012, 18.13], [37.40406, -4.497797, 35.15], [37.410237, -5.9253979999999995, 18.42], [37.412859, -5.981811, 28.57], [37.426014, -5.983239, 19.9], [37.42603, -5.97097, 32.66], [37.444389, -4.274673, 22.97], [37.446878, -7.106609, 37.31], [37.460876, -5.656487, 47.45], [37.475284, -4.440176, 28.55], [37.478254, -6.008443, 17.1], [37.573178, -0.922659, 13.81], [37.607613, -0.803816, 14.01], [37.66721, -1.70185, 27.82], [37.762187, -3.94021, 43.1], [37.76577, -6.5769400000000005, 16.71], [37.784414, -3.776479, 32.02], [37.7978776, -0.8383811, 40.58], [37.900654, -4.768967, 37.34], [37.957262, -2.434524, 34.72], [37.973403, -3.802544, 20.29], [37.992193, -0.674701, 16.72], [37.993743, -1.130865, 27.54], [38.019988, -3.370622, 13.97], [38.027699, -1.169062, 34.21], [38.035111, -1.253361, 31.39], [38.251086, -2.890412, 30.17], [38.272536, -0.6685329999999999, 33.06], [38.275878, -0.538824, 46.13], [38.336721, -0.501862, 32.94], [38.345149, -0.550284, 24.0], [38.3588695, -0.48505669999999995, 17.59], [38.376096, -0.498731, 39.99], [38.385687, -0.765061, 39.71], [38.5366, -0.1517, 24.21], [38.537481, -0.179914, 34.24], [38.568, -0.209723, 33.35], [38.615911, -1.08408, 22.31], [38.637127, -0.866327, 19.67], [38.667596, -4.037644, 41.98], [38.6999809, 0.13428199999999998, 41.91], [38.729447, 0.091984, 37.95], [38.7600947, -3.3876474, 36.82], [38.779339, -3.389307, 13.14], [38.794902, 0.179311, 30.8], [38.81955, -0.378237, 41.52], [38.821998, -0.001921, 17.12], [38.839523, -6.6469570000000004, 42.84], [38.8675825, -6.9896437, 24.71], [38.87883, -1.1002, 26.84], [38.89818, -6.99012, 25.42], [38.913286, -0.5532311999999999, 13.56], [38.94926, -0.195079, 30.11], [38.9710051, -0.1

# %% [markdown]
# No parece que haya diferencias entre importe y el precio total.
# Tambien parece que Depende mas del numero de estacioes que del o gasto

# %%
df_map = data_ev[data_ev['estacion.tarifa']=="AC"].groupby(['estacion.lat', 'estacion.lon'])['estacion.tarifa'].count().reset_index()

# Crear mapa centrado (ejemplo: centro de España)
m = folium.Map(location=[40.0, -3.7], zoom_start=6, tiles="CartoDB positron")

# Preparar datos para el HeatMap (lat, lon, peso)
heat_data = [[row['estacion.lat'], row['estacion.lon'], row['estacion.tarifa']] for index, row in df_map.iterrows()]

# Añadir capa HeatMap
HeatMap(heat_data, radius=15, blur=10, max_zoom=1).add_to(m)

# Mostrar en Jupyter
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee4684281514976aaec1b17e945ca96c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee4684281514976aaec1b17e945ca96c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee4684281514976aaec1b17e945ca96c = L.map(
#                 &quot;map_ee4684281514976aaec1b17e945ca96c&quot;,
#                 {
#                     center: [40.0, -3.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5dc41f9cdfc4d32f930ac7dbca91767 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c5dc41f9cdfc4d32f930ac7dbca91767.addTo(map_ee4684281514976aaec1b17e945ca96c);
#
#
#             var heat_map_4babb4c3de3624bf2cb61b2fd2ac69f1 = L.heatLayer(
#                 [[27.795289, -15.704981, 1.0], [27.8191842, -15.763147, 1.0], [28.1143065, -15.4487773, 1.0], [28.115359, -15.420044, 1.0], [28.496343, -13.863596, 1.0], [28.496423, -13.863676, 1.0], [36.494718, -6.264587, 1.0], [37.187365, -3.610366, 1.0], [37.190264, -3.605473, 2.0], [37.364876, -5.978485, 1.0], [37.393397, -5.982012, 1.0], [37.446878, -7.106609, 1.0], [37.573178, -0.922659, 1.0], [37.607613, -0.803816, 1.0], [37.76577, -6.5769400000000005, 1.0], [38.3588695, -0.48505669999999995, 1.0], [39.052552, 1.490513, 1.0], [39.468279, -0.374625, 1.0], [39.46942, 3.14841, 1.0], [39.46948, -0.39081000000000005, 1.0], [39.48137, -0.391, 1.0], [39.48927, -0.39006, 1.0], [39.500187, -0.40821399999999997, 1.0], [39.6017, 2.655697, 1.0], [40.086089, -3.870298, 1.0], [40.219114, -3.783749, 1.0], [40.397884, -3.6842509999999997, 1.0], [40.401129, -3.690088, 1.0], [40.423353, -3.699963, 1.0], [40.509927, -3.690702, 1.0], [40.514395, -3.6717589999999998, 1.0], [40.570622, -3.9260729999999997, 1.0], [40.675908, -3.615757, 1.0], [41.231611, 1.78483, 1.0], [41.296628, -3.751337, 1.0], [41.32972, 2.046081, 1.0], [41.332998, 2.09999, 1.0], [41.357185, 2.127859, 2.0], [41.372803, 2.154058, 1.0], [41.37592, 2.188999, 1.0], [41.385746, 2.127802, 1.0], [41.390684, -5.264096, 1.0], [41.39696, 2.14337, 1.0], [41.40173, 2.120758, 1.0], [41.42006, 2.201705, 1.0], [41.462425, 2.009037, 1.0], [41.480134, 2.064758, 1.0], [41.490216, 2.106902, 1.0], [41.508529, 2.138352, 1.0], [41.533251, 2.439732, 1.0], [41.537176, 2.444283, 1.0], [41.591375, -4.829591, 1.0], [41.624208, 0.623409, 1.0], [41.648342, -0.877761, 1.0], [41.657711, -4.741015, 1.0], [41.65956, -0.9891900000000001, 1.0], [41.673534, -4.724452, 1.0], [41.694479, -3.684933, 1.0], [41.751659, 1.876798, 1.0], [42.159568, 1.8575819999999998, 1.0], [42.193978, -7.80485, 1.0], [42.31468, 2.170948, 1.0], [42.320679, -1.5741209999999999, 1.0], [42.443736, 1.906463, 1.0], [42.46339, -2.43402, 1.0], [42.464557, -2.446848, 1.0], [42.80592, -1.66591, 1.0], [43.205168, -2.772871, 1.0], [43.224345, -2.817532, 1.0], [43.27054, -2.942303, 1.0], [43.27776, -2.840911, 1.0], [43.289171, -2.991716, 1.0], [43.293632, -2.092501, 1.0], [43.301117, -2.012309, 1.0], [43.31092, -3.05676, 1.0], [43.311259, -3.053486, 1.0], [43.323917, -1.971778, 1.0], [43.383335, -6.074988, 1.0], [43.383806, -4.399194, 1.0], [43.416616, -5.810642, 1.0], [43.555489, -5.921123, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 1,
#   &quot;radius&quot;: 15,
#   &quot;blur&quot;: 10,
# }
#             );
#
#
#             heat_map_4babb4c3de3624bf2cb61b2fd2ac69f1.addTo(map_ee4684281514976aaec1b17e945ca96c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# LA localizacion es algo distinta de DC y AC, aunque seguramente es porque hay menos tickect de AC

# %%
data_ev.groupby('lineas.kwh')["lineas.precioUnitario"].median()


trace1 = go.Scatter(
                    x = data_ev[data_ev['estacion.tarifa']=="AC"]['fechaEmision'],
                    y = data_ev[data_ev['estacion.tarifa']=="AC"]['lineas.precioUnitario'],
                    name = 'AC',
                    mode = 'markers',)


trace2 = go.Scatter(
                    x = data_ev[data_ev['estacion.tarifa']=="DC"]['fechaEmision'],
                    y = data_ev[data_ev['estacion.tarifa']=="DC"]['lineas.precioUnitario'],
                    name = 'DC',
                    mode = 'markers',)

layout=go.Layout(
            xaxis= dict(title= 'fecha',ticklen= 5,zeroline= False),
              yaxis= dict(title= 'precioUnitario',ticklen= 5,zeroline= False)
)
fig = go.Figure(data = [trace1, trace2])
iplot(fig)

# %% [markdown]
# No hay no hay estacionalidad en el tiempo

# %% [markdown]
# No hay diferecencia entre empresa

# %%
trace1 = go.Scatter(
                    x = data_ev[data_ev['idUsuario']=="EMP04-U28"]['fechaEmision'],
                    y = data_ev[data_ev['idUsuario']=="EMP04-U28"]['lineas.precioUnitario'],
                    name = 'EMP04-U28',
                    mode = 'markers',)

trace2 = go.Scatter(
                    x = data_ev[data_ev['idUsuario']=="EMP04-U29"]['fechaEmision'],
                    y = data_ev[data_ev['idUsuario']=="EMP04-U29"]['lineas.precioUnitario'],
                    name = 'EMP04-U29',
                    mode = 'markers',)
trace3 = go.Scatter(
                    x = data_ev[data_ev['idUsuario']=="EMP04-U30"]['fechaEmision'],
                    y = data_ev[data_ev['idUsuario']=="EMP04-U30"]['lineas.precioUnitario'],
                    name = 'EMP04-U30',
                    mode = 'markers',)

trace4 = go.Scatter(
                    x = data_ev[data_ev['idUsuario']=="EMP05-U31"]['fechaEmision'],
                    y = data_ev[data_ev['idUsuario']=="EMP05-U31"]['lineas.precioUnitario'],
                    name = 'EMP05-U31',
                    mode = 'markers',)

trace5 = go.Scatter(
                    x = data_ev[data_ev['idUsuario']=="EMP05-U32"]['fechaEmision'],
                    y = data_ev[data_ev['idUsuario']=="EMP05-U32"]['lineas.precioUnitario'],
                    name = 'EMP05-U32',
                    mode = 'markers',)

trace6 = go.Scatter(
                    x = data_ev[data_ev['idUsuario']=="EMP05-U33"]['fechaEmision'],
                    y = data_ev[data_ev['idUsuario']=="EMP05-U33"]['lineas.precioUnitario'],
                    name = 'EMP05-U33',
                    mode = 'markers',)

trace7 = go.Scatter(
                    x = data_ev[data_ev['idUsuario']=="EMP06-U34"]['fechaEmision'],
                    y = data_ev[data_ev['idUsuario']=="EMP06-U34"]['lineas.precioUnitario'],
                    name = 'EMP06-U34',
                    mode = 'markers',)

trace8 = go.Scatter(
                    x = data_ev[data_ev['idUsuario']=="EMP06-U35"]['fechaEmision'],
                    y = data_ev[data_ev['idUsuario']=="EMP06-U35"]['lineas.precioUnitario'],
                    name = 'EMP06-U35',
                    mode = 'markers',)
trace9 = go.Scatter(
                    x = data_ev[data_ev['idUsuario']=="EMP06-U36"]['fechaEmision'],
                    y = data_ev[data_ev['idUsuario']=="EMP06-U36"]['lineas.precioUnitario'],
                    name = 'EMP06-U36',
                    mode = 'markers',)

layout=go.Layout(
            xaxis= dict(title= 'fecha',ticklen= 5,zeroline= False),
              yaxis= dict(title= 'precioUnitario',ticklen= 5,zeroline= False)
)
fig = go.Figure(data = [trace1, trace2, trace3,trace4, trace5, trace6, trace7, trace8, trace9])
iplot(fig)

# %% [markdown]
# No hay deferencia significativa entre usuarios ni empresa
