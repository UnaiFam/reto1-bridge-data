# %%
import pandas as pd

data_ev=pd.read_json("Script_generador_tickets_sinteticos_electricos/data/tickets_ev_sinteticos.json")

# %%
# %pip install ipykernel -U force-reinstall
# Out:
# Requirement already satisfied: ipykernel in c:\users\unaif\appdata\roaming\python\python312\site-packages (6.29.5)
# Collecting ipykernel
#   Downloading ipykernel-6.30.1-py3-none-any.whl.metadata (6.2 kB)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement force-reinstall (from versions: none)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for force-reinstall

# %%
data_gas=pd.read_json("Script_generador_tickets_sinteticos_gasolina/data/tickets/tickets_sinteticos.json",convert_dates=True )

# %%
data_gas
# Out:
#            idTicket idEmpresa       empresaNombre    idUsuario fechaEmision  \
# 0    T-0C1311ADF29F    EMP001  Transporte_01 S.L.  EMP001-U001   2025-04-13
# 1    T-55903B782FD8    EMP001  Transporte_01 S.L.  EMP001-U001   2025-06-14
# 2    T-3B130BF0D608    EMP001  Transporte_01 S.L.  EMP001-U001   2025-01-03
# 3    T-C3C4181BF9CE    EMP001  Transporte_01 S.L.  EMP001-U001   2025-06-04
# 4    T-AC20A854020A    EMP001  Transporte_01 S.L.  EMP001-U001   2025-07-26
# ..              ...       ...                 ...          ...          ...
# 445  T-421120F7789A    EMP003  Transporte_03 S.L.  EMP003-U003   2025-01-01
# 446  T-6EB13665A488    EMP003  Transporte_03 S.L.  EMP003-U003   2025-05-13
# 447  T-6472D962E149    EMP003  Transporte_03 S.L.  EMP003-U003   2025-04-26
# 448  T-24235689921D    EMP003  Transporte_03 S.L.  EMP003-U003   2025-06-27
# 449  T-992D39174800    EMP003  Transporte_03 S.L.  EMP003-U003   2025-06-13
#
#     horaEmision          metodoPago  \
# 0      04:23:15  Tarjeta de empresa
# 1      00:57:19  Tarjeta de empresa
# 2      13:38:09  Tarjeta de empresa
# 3      00:23:23  Tarjeta de empresa
# 4      17:43:18  Tarjeta de empresa
# ..          ...                 ...
# 445    21:49:05  Tarjeta de empresa
# 446    04:09:58  Tarjeta de empresa
# 447    18:28:03  Tarjeta de empresa
# 448    21:49:59  Tarjeta de empresa
# 449    22:26:52  Tarjeta de empresa
#
#                                               estacion  \
# 0    {'id': '1492', 'nombre': 'COOP. LA SIBERIA EXT...
# 1    {'id': '6170', 'nombre': 'E.S SANT ISIDRE', 'p...
# 2    {'id': '3956', 'nombre': 'REPSOL', 'provincia'...
# 3    {'id': '550', 'nombre': 'GLOBAL OIL', 'provinc...
# 4    {'id': '451', 'nombre': 'BP', 'provincia': 'AL...
# ..                                                 ...
# 445  {'id': '1862', 'nombre': 'REPSOL', 'provincia'...
# 446  {'id': '11773', 'nombre': 'CAMPO DE USED', 'pr...
# 447  {'id': '10784', 'nombre': 'BP ALGEMESI II - LA...
# 448  {'id': '9981', 'nombre': 'RED CAR OIL', 'provi...
# 449  {'id': '10487', 'nombre': 'PRADOGAS, S.COOP. D...
#
#                                                 lineas  baseImponible    iva  \
# 0    [{'producto': 'Gasolina 95 E5', 'litros': 17.4...          21.62   4.54
# 1    [{'producto': 'Gasolina 95 E5', 'litros': 25.6...          31.55   6.63
# 2    [{'producto': 'Gasóleo A', 'litros': 50.44, 'p...          59.78  12.55
# 3    [{'producto': 'Gasolina 98 E5', 'litros': 23.0...          32.48   6.82
# 4    [{'producto': 'Gasóleo A', 'litros': 52.21, 'p...          62.22  13.07
# ..                                                 ...            ...    ...
# 445  [{'producto': 'Gasóleo Premium', 'litros': 27....          33.91   7.12
# 446  [{'producto': 'Gasolina 98 E5', 'litros': 52.3...          74.24  15.59
# 447  [{'producto': 'Gasolina 98 E5', 'litros': 15.2...          21.94   4.61
# 448  [{'producto': 'Gasolina 98 E5', 'litros': 46.4...          65.12  13.67
# 449  [{'producto': 'Gasóleo A', 'litros': 33.24, 'p...          39.92   8.38
#
#      total moneda         tipoDocumento
# 0    26.16    EUR  Factura simplificada
# 1    38.18    EUR  Factura simplificada
# 2    72.33    EUR  Factura simplificada
# 3    39.30    EUR  Factura simplificada
# 4    75.29    EUR  Factura simplificada
# ..     ...    ...                   ...
# 445  41.03    EUR  Factura simplificada
# 446  89.83    EUR  Factura simplificada
# 447  26.55    EUR  Factura simplificada
# 448  78.79    EUR  Factura simplificada
# 449  48.30    EUR  Factura simplificada
#
# [450 rows x 14 columns]

# %%
data_gas["lineas"]
# Out:
# 0      [{'producto': 'Gasolina 95 E5', 'litros': 17.4...
# 1      [{'producto': 'Gasolina 95 E5', 'litros': 25.6...
# 2      [{'producto': 'Gasóleo A', 'litros': 50.44, 'p...
# 3      [{'producto': 'Gasolina 98 E5', 'litros': 23.0...
# 4      [{'producto': 'Gasóleo A', 'litros': 52.21, 'p...
#                              ...
# 445    [{'producto': 'Gasóleo Premium', 'litros': 27....
# 446    [{'producto': 'Gasolina 98 E5', 'litros': 52.3...
# 447    [{'producto': 'Gasolina 98 E5', 'litros': 15.2...
# 448    [{'producto': 'Gasolina 98 E5', 'litros': 46.4...
# 449    [{'producto': 'Gasóleo A', 'litros': 33.24, 'p...
# Name: lineas, Length: 450, dtype: object

# %%
estacion_df = pd.json_normalize(data_gas["estacion"])
data_gas = data_gas.drop(columns=["estacion"]).join(estacion_df.add_prefix("estacion."))

# %%
df_exploded = data_gas.explode("lineas").reset_index(drop=True)

# Normaliza la columna "lineas" (dict → columnas)
lineas_normalizadas = pd.json_normalize(df_exploded["lineas"])

# Une las nuevas columnas con el dataset original
data_gas = df_exploded.drop(columns=["lineas"]).join(lineas_normalizadas.add_prefix("lineas."))

# %%
data_gas["fechaEmision"]=pd.to_datetime(data_gas["fechaEmision"])
data_gas["horaEmision"]=pd.to_datetime(data_gas["horaEmision"])
# Out:
# C:\Users\unaif\AppData\Local\Temp\ipykernel_31928\3642091836.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data_gas["horaEmision"]=pd.to_datetime(data_gas["horaEmision"])

# %%
data_gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   idTicket               450 non-null    object
#  1   idEmpresa              450 non-null    object
#  2   empresaNombre          450 non-null    object
#  3   idUsuario              450 non-null    object
#  4   fechaEmision           450 non-null    datetime64[ns]
#  5   horaEmision            450 non-null    datetime64[ns]
#  6   metodoPago             450 non-null    object
#  7   baseImponible          450 non-null    float64
#  8   iva                    450 non-null    float64
#  9   total                  450 non-null    float64
#  10  moneda                 450 non-null    object
#  11  tipoDocumento          450 non-null    object
#  12  estacion.id            450 non-null    object
#  13  estacion.nombre        450 non-null    object
#  14  estacion.provincia     450 non-null    object
#  15  estacion.municipio     450 non-null    object
#  16  estacion.direccion     450 non-null    object
#  17  estacion.lat           450 non-null    float64
#  18  estacion.lon           450 non-null    float64
#  19  estacion.grupo         450 non-null    object
#  20  estacion.nifEmpresa    450 non-null    object
#  21  lineas.producto        450 non-null    object
#  22  lineas.litros          450 non-null    float64
#  23  lineas.precioUnitario  450 non-null    float64
#  24  lineas.importe         450 non-null    float64
# dtypes: datetime64[ns](2), float64(8), object(15)
# memory usage: 88.0+ KB

# %%
data_gas['empresaNombre']
# Out:
# 0      Transporte_01 S.L.
# 1      Transporte_01 S.L.
# 2      Transporte_01 S.L.
# 3      Transporte_01 S.L.
# 4      Transporte_01 S.L.
#               ...
# 445    Transporte_03 S.L.
# 446    Transporte_03 S.L.
# 447    Transporte_03 S.L.
# 448    Transporte_03 S.L.
# 449    Transporte_03 S.L.
# Name: empresaNombre, Length: 450, dtype: object

# %%
[['empresaNombre', 'idUsuario', 'fechaEmision', 'horaEmision', 'metodoPago', 'baseImponible', 'total', 'estacion.id', 'estacion.provincia']]
# Out:
# [['empresaNombre',
#   'idUsuario',
#   'fechaEmision',
#   'horaEmision',
#   'metodoPago',
#   'baseImponible',
#   'total',
#   'estacion.id',
#   'estacion.provincia']]

# %%
from skrub import TableReport

TableReport(data_gas)
# Out:
# Processing column  25 / 25
# <TableReport: use .open() to display>

# %%
data_gas["idEmpresa"].value_counts()
# Out:
# idEmpresa
# EMP001    150
# EMP002    150
# EMP003    150
# Name: count, dtype: int64

# %%
data_gas['estacion.nombre'].value_counts()
# Out:
# estacion.nombre
# REPSOL                           113
# CEPSA                             27
# MOEVE                             21
# GALP                              15
# BALLENOIL                         11
#                                 ...
# BDMED                              1
# CAMPO DE USED                      1
# BP ALGEMESI II - LA CALANDRIA      1
# RED CAR OIL                        1
# PRADOGAS, S.COOP. DE C-LM          1
# Name: count, Length: 205, dtype: int64

# %%
data_gas.fechaEmision.max()
# Out:
# Timestamp('2025-07-31 00:00:00')

# %% [markdown]
# Abril es el maes eque mas se reponsto
# El metodo de pago mas comuns es la tarjete de empresa
# Las fechas van desde enero a 31 julio
# Lo normal es gastar 63 euros en gasoluna ( o unos 42 litros )
# Repsos es la esacion mas comuns

# %%
data_gas['lineas.producto'].value_counts()
# Out:
# lineas.producto
# Gasolina 98 E5     126
# Gasóleo Premium    115
# Gasóleo A          114
# Gasolina 95 E5      95
# Name: count, dtype: int64

# %%
TableReport(data_gas[data_gas['estacion.nombre']=="REPSOL"])
# Out:
# Processing column  25 / 25
# <TableReport: use .open() to display>

# %% [markdown]
# Repsol no es la mas barata al contrario de lo esperaple

# %%
data_gas.groupby('estacion.nombre')["lineas.precioUnitario"].median()
# Out:
# estacion.nombre
#  E.S. LA TORRETA                         1.7200
# AGLA                                     1.6530
# AGROPAL                                  1.6570
# AIRA SILLEDA                             1.5630
# ALIARA ENERGIA                           1.5370
#                                           ...
# VALCARCE                                 1.5165
# VALCARCE (GHC )                          1.7280
# VALCOR SOCIEDAD COOPERATIVA ASTURIANA    1.7320
# VCC ANOUER                               1.5290
# VILLAGER                                 1.5190
# Name: lineas.precioUnitario, Length: 205, dtype: float64

# %% [markdown]
# Lo mas barato es Villager

# %%
data_gas.groupby('lineas.producto')["lineas.precioUnitario"].median()
# Out:
# lineas.producto
# Gasolina 95 E5     1.521
# Gasolina 98 E5     1.704
# Gasóleo A          1.441
# Gasóleo Premium    1.539
# Name: lineas.precioUnitario, dtype: float64

# %%
data_gas.groupby('estacion.grupo')["lineas.precioUnitario"].median()
# Out:
# estacion.grupo
#  E.S. LA TORRETA                         1.7200
# AGLA                                     1.6530
# AGROPAL                                  1.6570
# AIRA SILLEDA                             1.5630
# ALIARA ENERGIA                           1.5370
#                                           ...
# VALCARCE                                 1.5165
# VALCARCE (GHC )                          1.7280
# VALCOR SOCIEDAD COOPERATIVA ASTURIANA    1.7320
# VCC ANOUER                               1.5290
# VILLAGER                                 1.5190
# Name: lineas.precioUnitario, Length: 205, dtype: float64

# %% [markdown]
# Lo mas barato es el gasoleo A

# %%
import folium
from folium import plugins
mapa = folium.Map(location=[40, -5], zoom_start=6, )
for x in range(len(data_gas)):
         
    
    folium.Marker(location=data_gas.iloc[x][["estacion.lat","estacion.lon"]], popup=data_gas.iloc[x]["lineas.precioUnitario"]
              
              ).add_to(mapa)

mapa
# Out:
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# ...
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# c:\Users\unaif\anaconda3\envs\venv\Lib\site-packages\folium\utilities.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coords = (location[0], location[1])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ff5b11915db702c16d8dc7f21010c28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ff5b11915db702c16d8dc7f21010c28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ff5b11915db702c16d8dc7f21010c28 = L.map(
#                 &quot;map_5ff5b11915db702c16d8dc7f21010c28&quot;,
#                 {
#                     center: [40.0, -5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ed5fb8c0752094df6ca5b7f03981853 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ed5fb8c0752094df6ca5b7f03981853.addTo(map_5ff5b11915db702c16d8dc7f21010c28);
#
#
#             var marker_9d02185d32d8078ed481f0c1e57d94d6 = L.marker(
#                 [39.042917, -5.234583],
#                 {
# }
#             ).addTo(map_5ff5b11915db702c16d8dc7f21010c28);
#
#
#         var popup_087449b2004184330d7d571493a07a15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e738695e304087cc0375406ad731f97 = $(`&lt;div id=&quot;html_0e738695e304087cc0375406ad731f97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1.5&lt;/div&gt;`)[0];
#                 popup_087449b2004184330d7d571493a07a15.setContent(html_0e738695e304087cc0375406ad731f97);
#
#
#
#         marker_9d02185d32d8078ed481f0c1e57d94d6.bindPopup(popup_087449b2004184330d7d571493a07a15)
#         ;
#
#
#
#
#             var marker_60010ae7f951ee021cc1cf7e262bf0cc = L.marker(
#                 [41.523167, 0.861694],
#                 {
# }
#             ).addTo(map_5ff5b11915db702c16d8dc7f21010c28);
#
#
#         var popup_e1e0b1fdb471adabf6ed1a7e859cc38f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b1ccdcf183191ebad221842734cb5db = $(`&lt;div id=&quot;html_5b1ccdcf183191ebad221842734cb5db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1.4889999999999999&lt;/div&gt;`)[0];
#                 popup_e1e0b1fdb471adabf6ed1a7e859cc38f.setContent(html_5b1ccdcf183191ebad221842734cb5db);
#
#
#
#         marker_60010ae7f951ee021cc1cf7e262bf0cc.bindPopup(popup_e1e0b1fdb471adabf6ed1a7e859cc38f)
#         ;
#
#
#
#
#             var marker_9ad86dd917b2d7421c9c31ef83b69226 = L.marker(
#                 [37.691333, -4.486028],
#                 {
# }
#             ).addTo(map_5ff5b11915db702c16d8dc7f21010c28);
#
#
#         var popup_617e624bcadb16271efa6b4d2b7859b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d9bdb8bca9dd9689dfa70f5c02f256b = $(`&lt;div id=&quot;html_8d9bdb8bca9dd9689dfa70f5c02f256b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1.434&lt;/div&gt;`)[0];
#                 popup_617e624bcadb16271efa6b4d2b7859b3.setContent(html_8d9bdb8bca9dd9689dfa70f5c02f256b);
#
#
#
#         marker_9ad86dd917b2d7421c9c31ef83b69226.bindPopup(popup_617e624bcadb16271efa6b4d2b7859b3)
#         ;
#
#
#
#
#             var marker_9d045cb163e0647210ccb65b1b28b3dc = L.marker(
#                 [37.990083, -0.7994439999999999],
#                 {
# }
#             ).addTo(map_5ff5b11915db702c16d8dc7f21010c28);
#
#
#         var popup_3f468f5dc15ed319592bcca6411220cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61efed0a85e6ee52998b232fe9cc83ca = $(`&lt;div id=&quot;html_61efed0a85e6ee52998b232fe9cc83ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1.7069999999999999&lt;/div&gt;`)[0];
#                 popup_3f468f5dc15ed319592bcca6411220cc.setContent(html_61efed0a85e6ee52998b232fe9cc83ca);
#
#
#
#         marker_9d045cb163e0647210ccb65b1b28b3dc.bindPopup(popup_3f468f5dc15ed319592bcca6411220cc)
#         ;
#
#
#
#
#             var marker_7111838c0788aca89d2ae91ebb59fb94 = L.marker(
#                 [38.74075, 0.150944],
#                 {
# }
#             ).addTo(map_5ff5b11915db702c16d8dc7f21010c28);
#
#
#         var popup_119e814f926fe3517c8f532edf5f292d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93f8216b57b7866e9ca7b0718ab7c032 = $(`&lt;div id=&quot;html_93f8216b57b7866e9ca7b0718ab7c032&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1.442&lt;/div&gt;`)[0];
#                 popup_119e814f926fe3517c8f532edf5f292d.setContent(html_93f8216b57b7866e9ca7b0718ab7c032);
#
#
#
#         marker_7111838c0788aca89d2ae
